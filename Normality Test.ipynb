# %%
import numpy as np
from scipy  import stats
import matplotlib.pyplot as plt

# %%
x = [1.27,1.36,1.28,1.31,1.35,1.2,1.39,1.35,1.41,1.31,
    1.2,1.26,1.31,1.49,1.32,1.4,1.33,1.28,1.29,1.39,
    1.38,1.34,1.44,1.27,1.33,1.38,1.43,1.29,1.34]
x
# Out:
# [1.27,
#  1.36,
#  1.28,
#  1.31,
#  1.35,
#  1.2,
#  1.39,
#  1.35,
#  1.41,
#  1.31,
#  1.2,
#  1.26,
#  1.31,
#  1.49,
#  1.32,
#  1.4,
#  1.33,
#  1.28,
#  1.29,
#  1.39,
#  1.38,
#  1.34,
#  1.44,
#  1.27,
#  1.33,
#  1.38,
#  1.43,
#  1.29,
#  1.34]

# %%
stats.probplot(x,plot=plt)
plt.show()

# %%
stats.shapiro(x)
# Out:
# ShapiroResult(statistic=0.9852076768875122, pvalue=0.9462102651596069)

# %%
stats.kstest(x,"norm")
# Out:
# KstestResult(statistic=0.8849303297782918, pvalue=1.184095751827836e-27, statistic_location=1.2, statistic_sign=-1)

# %%
stats.anderson(x,dist='norm')
# Out:
# AndersonResult(statistic=0.16886399964690568, critical_values=array([0.52 , 0.592, 0.71 , 0.828, 0.985]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=1.33448275862069, scale=0.06759047940652542)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
stats.anderson(x, dist='logistic')
# Out:
# AndersonResult(statistic=0.1678552892655638, critical_values=array([0.422, 0.558, 0.654, 0.762, 0.898, 1.001]), significance_level=array([25. , 10. ,  5. ,  2.5,  1. ,  0.5]), fit_result=  params: FitParams(loc=1.3336932230382337, scale=0.03794423149235676)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
stats.anderson(x, dist='extreme1')
# Out:
# AndersonResult(statistic=0.5487383122649838, critical_values=array([0.457, 0.614, 0.73 , 0.846, 1.001]), significance_level=array([25. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=1.367988083708661, scale=0.06650129066542962)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
stats.anderson(x, dist='expon')
# Out:
# AndersonResult(statistic=12.052110471717917, critical_values=array([0.903, 1.056, 1.314, 1.573, 1.917]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=0.0, scale=1.33448275862069)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
