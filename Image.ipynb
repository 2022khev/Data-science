# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\kelvin\ImagesVehicles\train\cars\Image_17.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('image.17',img)

# %%
# cv2.waitKey(0)

# %%
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()

# %%
import matplotlib.pyplot as plt
rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(img,cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt
# rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# plt.axis('off')
plt.imshow(img)
plt.show()

# %%
# !pip  install ultralytics
